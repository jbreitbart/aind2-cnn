# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /home/jbreitbart/.anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 9s - loss: 1.5872 - acc: 0.4230 - val_loss: 1.6113 - val_acc: 0.4398
#
# Epoch 00001: val_loss improved from inf to 1.61127, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 7s - loss: 1.2893 - acc: 0.5363 - val_loss: 1.2125 - val_acc: 0.5730
#
# Epoch 00002: val_loss improved from 1.61127 to 1.21254, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 7s - loss: 1.1701 - acc: 0.5842 - val_loss: 1.1388 - val_acc: 0.5844
#
# Epoch 00003: val_loss improved from 1.21254 to 1.13876, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 7s - loss: 1.0997 - acc: 0.6122 - val_loss: 1.0972 - val_acc: 0.6370
#
# Epoch 00004: val_loss improved from 1.13876 to 1.09718, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 7s - loss: 1.0585 - acc: 0.6303 - val_loss: 1.0037 - val_acc: 0.6506
#
# Epoch 00005: val_loss improved from 1.09718 to 1.00369, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 7s - loss: 1.0297 - acc: 0.6448 - val_loss: 0.9466 - val_acc: 0.6676
#
# Epoch 00006: val_loss improved from 1.00369 to 0.94655, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 7s - loss: 1.0173 - acc: 0.6515 - val_loss: 1.1210 - val_acc: 0.6206
#
# Epoch 00007: val_loss did not improve from 0.94655
# Epoch 8/100
#  - 7s - loss: 1.0146 - acc: 0.6566 - val_loss: 1.2706 - val_acc: 0.5594
#
# Epoch 00008: val_loss did not improve from 0.94655
# Epoch 9/100
#  - 7s - loss: 1.0229 - acc: 0.6512 - val_loss: 1.2347 - val_acc: 0.6108
#
# Epoch 00009: val_loss did not improve from 0.94655
# Epoch 10/100
#  - 7s - loss: 1.0332 - acc: 0.6504 - val_loss: 0.9944 - val_acc: 0.6698
#
# Epoch 00010: val_loss did not improve from 0.94655
# Epoch 11/100
#  - 7s - loss: 1.0421 - acc: 0.6485 - val_loss: 1.2093 - val_acc: 0.6190
#
# Epoch 00011: val_loss did not improve from 0.94655
# Epoch 12/100
#  - 7s - loss: 1.0528 - acc: 0.6473 - val_loss: 1.0078 - val_acc: 0.6834
#
# Epoch 00012: val_loss did not improve from 0.94655
# Epoch 13/100
#  - 7s - loss: 1.0709 - acc: 0.6416 - val_loss: 0.9720 - val_acc: 0.6768
#
# Epoch 00013: val_loss did not improve from 0.94655
# Epoch 14/100
#  - 7s - loss: 1.0935 - acc: 0.6371 - val_loss: 1.2921 - val_acc: 0.6306
#
# Epoch 00014: val_loss did not improve from 0.94655
# Epoch 15/100
#  - 7s - loss: 1.1070 - acc: 0.6293 - val_loss: 1.2595 - val_acc: 0.5692
#
# Epoch 00015: val_loss did not improve from 0.94655
# Epoch 16/100
#  - 7s - loss: 1.1311 - acc: 0.6247 - val_loss: 1.0360 - val_acc: 0.6578
#
# Epoch 00016: val_loss did not improve from 0.94655
# Epoch 17/100
#  - 7s - loss: 1.1392 - acc: 0.6246 - val_loss: 0.9501 - val_acc: 0.6842
#
# Epoch 00017: val_loss did not improve from 0.94655
# Epoch 18/100
#  - 7s - loss: 1.1703 - acc: 0.6127 - val_loss: 1.1024 - val_acc: 0.6398
#
# Epoch 00018: val_loss did not improve from 0.94655
# Epoch 19/100
#  - 7s - loss: 1.1865 - acc: 0.6096 - val_loss: 1.2022 - val_acc: 0.6014
#
# Epoch 00019: val_loss did not improve from 0.94655
# Epoch 20/100
#  - 7s - loss: 1.1987 - acc: 0.6033 - val_loss: 1.1556 - val_acc: 0.6344
#
# Epoch 00020: val_loss did not improve from 0.94655
# Epoch 21/100
#  - 7s - loss: 1.2183 - acc: 0.5979 - val_loss: 1.4688 - val_acc: 0.5942
#
# Epoch 00021: val_loss did not improve from 0.94655
# Epoch 22/100
#  - 7s - loss: 1.2341 - acc: 0.5894 - val_loss: 1.3321 - val_acc: 0.5638
#
# Epoch 00022: val_loss did not improve from 0.94655
# Epoch 23/100
#  - 7s - loss: 1.2593 - acc: 0.5826 - val_loss: 1.2592 - val_acc: 0.5838
#
# Epoch 00023: val_loss did not improve from 0.94655
# Epoch 24/100
#  - 7s - loss: 1.2575 - acc: 0.5827 - val_loss: 1.0768 - val_acc: 0.6316
#
# Epoch 00024: val_loss did not improve from 0.94655
# Epoch 25/100
#  - 7s - loss: 1.2843 - acc: 0.5732 - val_loss: 1.4466 - val_acc: 0.5160
#
# Epoch 00025: val_loss did not improve from 0.94655
# Epoch 26/100
#  - 7s - loss: 1.2957 - acc: 0.5689 - val_loss: 1.0823 - val_acc: 0.6376
#
# Epoch 00026: val_loss did not improve from 0.94655
# Epoch 27/100
#  - 7s - loss: 1.3176 - acc: 0.5615 - val_loss: 1.9551 - val_acc: 0.5396
#
# Epoch 00027: val_loss did not improve from 0.94655
# Epoch 28/100
#  - 7s - loss: 1.3472 - acc: 0.5530 - val_loss: 1.1565 - val_acc: 0.5986
#
# Epoch 00028: val_loss did not improve from 0.94655
# Epoch 29/100
#  - 7s - loss: 1.3665 - acc: 0.5466 - val_loss: 1.2087 - val_acc: 0.6284
#
# Epoch 00029: val_loss did not improve from 0.94655
# Epoch 30/100
#  - 7s - loss: 1.3640 - acc: 0.5449 - val_loss: 1.2514 - val_acc: 0.5890
#
# Epoch 00030: val_loss did not improve from 0.94655
# Epoch 31/100
#  - 7s - loss: 1.3923 - acc: 0.5389 - val_loss: 1.5716 - val_acc: 0.5022
#
# Epoch 00031: val_loss did not improve from 0.94655
# Epoch 32/100
#  - 7s - loss: 1.4006 - acc: 0.5347 - val_loss: 2.4827 - val_acc: 0.5258
#
# Epoch 00032: val_loss did not improve from 0.94655
# Epoch 33/100
#  - 7s - loss: 1.4080 - acc: 0.5275 - val_loss: 1.3704 - val_acc: 0.5072
#
# Epoch 00033: val_loss did not improve from 0.94655
# Epoch 34/100
#  - 7s - loss: 1.4274 - acc: 0.5208 - val_loss: 1.9553 - val_acc: 0.4484
#
# Epoch 00034: val_loss did not improve from 0.94655
# Epoch 35/100
#  - 7s - loss: 1.4522 - acc: 0.5167 - val_loss: 1.3409 - val_acc: 0.5520
#
# Epoch 00035: val_loss did not improve from 0.94655
# Epoch 36/100
#  - 7s - loss: 1.4605 - acc: 0.5131 - val_loss: 1.2593 - val_acc: 0.5862
#
# Epoch 00036: val_loss did not improve from 0.94655
# Epoch 37/100
#  - 7s - loss: 1.4647 - acc: 0.5057 - val_loss: 1.2759 - val_acc: 0.5496
#
# Epoch 00037: val_loss did not improve from 0.94655
# Epoch 38/100
#  - 7s - loss: 1.4782 - acc: 0.5044 - val_loss: 1.4171 - val_acc: 0.6010
#
# Epoch 00038: val_loss did not improve from 0.94655
# Epoch 39/100
#  - 7s - loss: 1.4932 - acc: 0.5012 - val_loss: 1.6333 - val_acc: 0.4984
#
# Epoch 00039: val_loss did not improve from 0.94655
# Epoch 40/100
#  - 7s - loss: 1.5030 - acc: 0.4984 - val_loss: 2.3089 - val_acc: 0.4650
#
# Epoch 00040: val_loss did not improve from 0.94655
# Epoch 41/100
#  - 7s - loss: 1.5121 - acc: 0.4955 - val_loss: 1.4741 - val_acc: 0.5264
#
# Epoch 00041: val_loss did not improve from 0.94655
# Epoch 42/100
#  - 7s - loss: 1.5201 - acc: 0.4899 - val_loss: 1.4602 - val_acc: 0.4998
#
# Epoch 00042: val_loss did not improve from 0.94655
# Epoch 43/100
#  - 7s - loss: 1.5171 - acc: 0.4932 - val_loss: 1.3216 - val_acc: 0.5362
#
# Epoch 00043: val_loss did not improve from 0.94655
# Epoch 44/100
#  - 7s - loss: 1.5156 - acc: 0.4880 - val_loss: 1.3438 - val_acc: 0.5172
#
# Epoch 00044: val_loss did not improve from 0.94655
# Epoch 45/100
#  - 7s - loss: 1.5402 - acc: 0.4800 - val_loss: 1.3553 - val_acc: 0.5404
#
# Epoch 00045: val_loss did not improve from 0.94655
# Epoch 46/100
#  - 7s - loss: 1.5421 - acc: 0.4827 - val_loss: 1.2402 - val_acc: 0.5700
#
# Epoch 00046: val_loss did not improve from 0.94655
# Epoch 47/100
#  - 7s - loss: 1.5402 - acc: 0.4775 - val_loss: 1.7398 - val_acc: 0.4240
#
# Epoch 00047: val_loss did not improve from 0.94655
# Epoch 48/100
#  - 7s - loss: 1.5549 - acc: 0.4722 - val_loss: 1.2511 - val_acc: 0.5686
#
# Epoch 00048: val_loss did not improve from 0.94655
# Epoch 49/100
#  - 7s - loss: 1.5667 - acc: 0.4716 - val_loss: 1.5791 - val_acc: 0.4278
#
# Epoch 00049: val_loss did not improve from 0.94655
# Epoch 50/100
#  - 7s - loss: 1.5656 - acc: 0.4697 - val_loss: 1.2801 - val_acc: 0.5408
#
# Epoch 00050: val_loss did not improve from 0.94655
# Epoch 51/100
#  - 7s - loss: 1.5580 - acc: 0.4701 - val_loss: 1.3152 - val_acc: 0.5334
#
# Epoch 00051: val_loss did not improve from 0.94655
# Epoch 52/100
#  - 7s - loss: 1.5494 - acc: 0.4729 - val_loss: 1.5085 - val_acc: 0.5214
#
# Epoch 00052: val_loss did not improve from 0.94655
# Epoch 53/100
#  - 7s - loss: 1.5734 - acc: 0.4658 - val_loss: 1.9574 - val_acc: 0.4466
#
# Epoch 00053: val_loss did not improve from 0.94655
# Epoch 54/100
#  - 7s - loss: 1.5808 - acc: 0.4693 - val_loss: 1.3778 - val_acc: 0.5202
#
# Epoch 00054: val_loss did not improve from 0.94655
# Epoch 55/100
#  - 7s - loss: 1.5889 - acc: 0.4604 - val_loss: 1.4120 - val_acc: 0.5106
#
# Epoch 00055: val_loss did not improve from 0.94655
# Epoch 56/100
#  - 7s - loss: 1.5894 - acc: 0.4597 - val_loss: 1.4319 - val_acc: 0.5008
#
# Epoch 00056: val_loss did not improve from 0.94655
# Epoch 57/100
#  - 7s - loss: 1.5909 - acc: 0.4520 - val_loss: 1.5317 - val_acc: 0.4298
#
# Epoch 00057: val_loss did not improve from 0.94655
# Epoch 58/100
#  - 7s - loss: 1.6074 - acc: 0.4489 - val_loss: 1.3458 - val_acc: 0.5374
# Epoch 00058: val_loss did not improve from 0.94655
# Epoch 59/100
#  - 7s - loss: 1.6166 - acc: 0.4465 - val_loss: 1.4493 - val_acc: 0.4490
#
# Epoch 00059: val_loss did not improve from 0.94655
# Epoch 60/100
#  - 7s - loss: 1.6146 - acc: 0.4491 - val_loss: 1.4925 - val_acc: 0.4320
#
# Epoch 00060: val_loss did not improve from 0.94655
# Epoch 61/100
#  - 7s - loss: 1.6231 - acc: 0.4436 - val_loss: 1.9494 - val_acc: 0.4744
#
# Epoch 00061: val_loss did not improve from 0.94655
# Epoch 62/100
#  - 7s - loss: 1.6336 - acc: 0.4363 - val_loss: 1.3778 - val_acc: 0.5068
#
# Epoch 00062: val_loss did not improve from 0.94655
# Epoch 63/100
#  - 7s - loss: 1.6215 - acc: 0.4424 - val_loss: 1.5178 - val_acc: 0.4442
#
# Epoch 00063: val_loss did not improve from 0.94655
# Epoch 64/100
#  - 7s - loss: 1.6286 - acc: 0.4384 - val_loss: 1.7817 - val_acc: 0.4100
#
# Epoch 00064: val_loss did not improve from 0.94655
# Epoch 65/100
#  - 7s - loss: 1.6322 - acc: 0.4352 - val_loss: 1.6016 - val_acc: 0.4262
#
# Epoch 00065: val_loss did not improve from 0.94655
# Epoch 66/100
#  - 7s - loss: 1.6341 - acc: 0.4382 - val_loss: 1.5099 - val_acc: 0.4500
#
# Epoch 00066: val_loss did not improve from 0.94655
# Epoch 67/100
#  - 7s - loss: 1.6543 - acc: 0.4306 - val_loss: 1.4254 - val_acc: 0.5000
#
# Epoch 00067: val_loss did not improve from 0.94655
# Epoch 68/100
#  - 7s - loss: 1.6355 - acc: 0.4342 - val_loss: 3.3458 - val_acc: 0.4046
#
# Epoch 00068: val_loss did not improve from 0.94655
# Epoch 69/100
#  - 7s - loss: 1.6397 - acc: 0.4331 - val_loss: 1.5918 - val_acc: 0.5194
#
# Epoch 00069: val_loss did not improve from 0.94655
# Epoch 70/100
#  - 7s - loss: 1.6494 - acc: 0.4270 - val_loss: 1.7285 - val_acc: 0.4584
#
# Epoch 00070: val_loss did not improve from 0.94655
# Epoch 71/100
#  - 7s - loss: 1.6543 - acc: 0.4312 - val_loss: 1.5075 - val_acc: 0.4820
#
# Epoch 00071: val_loss did not improve from 0.94655
# Epoch 72/100
#  - 7s - loss: 1.6737 - acc: 0.4194 - val_loss: 1.4507 - val_acc: 0.4866
#
# Epoch 00072: val_loss did not improve from 0.94655
# Epoch 73/100
#  - 7s - loss: 1.6999 - acc: 0.4152 - val_loss: 2.0100 - val_acc: 0.3672
#
# Epoch 00073: val_loss did not improve from 0.94655
# Epoch 74/100
#  - 7s - loss: 1.6931 - acc: 0.4168 - val_loss: 1.4494 - val_acc: 0.5026
#
# Epoch 00074: val_loss did not improve from 0.94655
# Epoch 75/100
#  - 7s - loss: 1.7084 - acc: 0.4115 - val_loss: 1.6352 - val_acc: 0.4368
#
# Epoch 00075: val_loss did not improve from 0.94655
# Epoch 76/100
#  - 7s - loss: 1.6848 - acc: 0.4108 - val_loss: 1.9170 - val_acc: 0.3484
#
# Epoch 00076: val_loss did not improve from 0.94655
# Epoch 77/100
#  - 7s - loss: 1.6883 - acc: 0.4098 - val_loss: 1.9159 - val_acc: 0.4454
#
# Epoch 00077: val_loss did not improve from 0.94655
# Epoch 78/100
#  - 7s - loss: 1.6987 - acc: 0.4071 - val_loss: 1.3989 - val_acc: 0.4936
#
# Epoch 00078: val_loss did not improve from 0.94655
# Epoch 79/100
#  - 7s - loss: 1.7010 - acc: 0.4078 - val_loss: 1.6032 - val_acc: 0.4894
#
# Epoch 00079: val_loss did not improve from 0.94655
# Epoch 80/100
#  - 7s - loss: 1.7130 - acc: 0.4073 - val_loss: 1.4009 - val_acc: 0.4984
#
# Epoch 00080: val_loss did not improve from 0.94655
# Epoch 81/100
#  - 7s - loss: 1.7012 - acc: 0.4077 - val_loss: 1.5389 - val_acc: 0.4586
#
# Epoch 00081: val_loss did not improve from 0.94655
# Epoch 82/100
#  - 7s - loss: 1.7028 - acc: 0.4052 - val_loss: 1.4731 - val_acc: 0.4840
#
# Epoch 00082: val_loss did not improve from 0.94655
# Epoch 83/100
#  - 7s - loss: 1.6859 - acc: 0.4072 - val_loss: 1.7496 - val_acc: 0.4312
#
# Epoch 00083: val_loss did not improve from 0.94655
# Epoch 84/100
#  - 7s - loss: 1.7037 - acc: 0.4056 - val_loss: 1.6355 - val_acc: 0.4166
#
# Epoch 00084: val_loss did not improve from 0.94655
# Epoch 85/100
#  - 7s - loss: 1.7023 - acc: 0.4034 - val_loss: 1.6873 - val_acc: 0.4850
#
# Epoch 00085: val_loss did not improve from 0.94655
# Epoch 86/100
#  - 7s - loss: 1.7170 - acc: 0.4012 - val_loss: 1.4163 - val_acc: 0.4922
#
# Epoch 00086: val_loss did not improve from 0.94655
# Epoch 87/100
#  - 7s - loss: 1.7177 - acc: 0.3995 - val_loss: 1.6600 - val_acc: 0.4144
#
# Epoch 00087: val_loss did not improve from 0.94655
# Epoch 88/100
#  - 7s - loss: 1.7372 - acc: 0.3963 - val_loss: 1.6148 - val_acc: 0.4152
#
# Epoch 00088: val_loss did not improve from 0.94655
# Epoch 89/100
#  - 7s - loss: 1.7386 - acc: 0.3911 - val_loss: 1.5065 - val_acc: 0.4944
#
# Epoch 00089: val_loss did not improve from 0.94655
# Epoch 90/100
#  - 7s - loss: 1.7497 - acc: 0.3900 - val_loss: 1.6399 - val_acc: 0.3860
#
# Epoch 00090: val_loss did not improve from 0.94655
# Epoch 91/100
#  - 7s - loss: 1.7528 - acc: 0.3866 - val_loss: 1.6569 - val_acc: 0.3776
#
# Epoch 00091: val_loss did not improve from 0.94655
# Epoch 92/100
#  - 7s - loss: 1.7473 - acc: 0.3889 - val_loss: 1.6315 - val_acc: 0.4180
#
# Epoch 00092: val_loss did not improve from 0.94655
# Epoch 93/100
#  - 7s - loss: 1.7646 - acc: 0.3847 - val_loss: 1.8010 - val_acc: 0.4186
#
# Epoch 00093: val_loss did not improve from 0.94655
# Epoch 94/100
#  - 7s - loss: 1.7590 - acc: 0.3860 - val_loss: 1.7098 - val_acc: 0.3288
#
# Epoch 00094: val_loss did not improve from 0.94655
# Epoch 95/100
#  - 7s - loss: 1.7512 - acc: 0.3880 - val_loss: 1.5489 - val_acc: 0.4018
#
# Epoch 00095: val_loss did not improve from 0.94655
# Epoch 96/100
#  - 7s - loss: 1.7826 - acc: 0.3763 - val_loss: 1.6821 - val_acc: 0.4076
#
# Epoch 00096: val_loss did not improve from 0.94655
# Epoch 97/100
#  - 7s - loss: 1.7681 - acc: 0.3842 - val_loss: 1.7837 - val_acc: 0.3192
#
# Epoch 00097: val_loss did not improve from 0.94655
# Epoch 98/100
#  - 7s - loss: 1.7624 - acc: 0.3769 - val_loss: 1.6063 - val_acc: 0.4464
#
# Epoch 00098: val_loss did not improve from 0.94655
# Epoch 99/100
#  - 7s - loss: 1.7760 - acc: 0.3810 - val_loss: 1.7541 - val_acc: 0.4058
#
# Epoch 00099: val_loss did not improve from 0.94655
# Epoch 100/100
#  - 7s - loss: 1.7890 - acc: 0.3767 - val_loss: 1.6000 - val_acc: 0.4870
#
# Epoch 00100: val_loss did not improve from 0.94655

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.665

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
